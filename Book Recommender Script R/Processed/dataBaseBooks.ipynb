# %%
import pandas as pd
import numpy as np
import pymysql

# %%
try:
    db = pymysql.connect("localhost","root","password","recommender")
    cursor = db.cursor();
except:
    print("Connection Error")

# %%
# read csv into data frames

df_books = pd.read_csv("processed_books.csv")

# %%
df_books.info() # 8336 entries
df_books.dropna(inplace=True)

#df_books.book_id.isnull().any()
#df_books.title.isnull().any()
#df_books.authors.isnull().any()
#df_books.image_url.isnull().any()
#df_books.average_rating.isnull().any()
#np.issubdtype(df_books.average_rating,np.number)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8329 entries, 0 to 8328
# Data columns (total 11 columns):
# X                    8329 non-null int64
# book_id              8329 non-null int64
# title                8329 non-null object
# authors              8329 non-null object
# language_code        8329 non-null object
# books_count          8329 non-null int64
# goodreads_book_id    8329 non-null int64
# average_rating       8329 non-null float64
# ratings_count        8329 non-null int64
# image_url            8329 non-null object
# small_image_url      8329 non-null object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 780.8+ KB

# %%
# write books to csv
df_books.to_csv('processed_books.csv')

# %%
# insert query
insert = "INSERT INTO books(bookID,title,authors,ratings,imageURL) VALUES(%s,%s,%s,%s,%s)"

# %%
for index,row in df_books.iterrows():
    bookID = row['book_id']
    title = row['title']
    authors = row['authors']
    ratings = row['average_rating']
    imageURL = row['image_url']
    
    ins = (bookID,title,authors,ratings,imageURL)
    
    
    try:
        cursor.execute(insert,ins)
        db.commit()
        print("Successful")
    except:
        print(ins)
        db.rollback()
        print(TypeError)
        print(ValueError)
        print("Exception Occured ")
# Out:
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# Successful
# ...

# %%
db.close()
